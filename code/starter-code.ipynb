# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The new format for the SAT was released in March 2016. As an employee of the College Board - the organization that administers the SAT - we are part of a team that tracks statewide participation and recommends where money is best spent to improve SAT participation rates. We will use the provided data and outside research to make recommendations about how the College Board might work to increase the participation rate in certain states.

# %% [markdown]
# ## Executive Summary
#
# We are focusing on three points that we uncovered through the SAT/ACT 2017 & 2018 data and based on these discoveries the College Board should work towards increasing the participation rate in those region further.
#
# Through our research we discovered that 3 states are exhibiting significant increase in their SAT particitpation rate due to regulations or contract changes
# There are strong regional affiliations associated with ACT versus SAT preference. Coastal progressive states tend to favor the SAT, while Midwestern and Mountain conservative states tend to favor the ACT.
# The SAT made clear gains in 2018 relative to the ACT. The states making these gains tended to be states in the 10-15% participation range. Targeting states in similar positions in the 2018 distribution should be promising for the College Board moving forward.
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %%
#Imports:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

os.getcwd()
# Out:
# '/Users/Wilson/Documents/GitHub/classes_copy/project_1/code'

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
os.listdir(os.getcwd())

sat_test = pd.read_csv('/Users/Wilson/Documents/GitHub/classes_copy/project_1/data/sat_2017.csv')

act_test = pd.read_csv('/Users/Wilson/Documents/GitHub/classes_copy/project_1/data/act_2017.csv')

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:
#sat_test first 10 rows
sat_test.head(10)
# Out:
#                   State Participation  Evidence-Based Reading and Writing  \
# 0               Alabama            5%                                 593
# 1                Alaska           38%                                 547
# 2               Arizona           30%                                 563
# 3              Arkansas            3%                                 614
# 4            California           53%                                 531
# 5              Colorado           11%                                 606
# 6           Connecticut          100%                                 530
# 7              Delaware          100%                                 503
# 8  District of Columbia          100%                                 482
# 9               Florida           83%                                 520
#
#    Math  Total
# 0   572   1165
# 1   533   1080
# 2   553   1116
# 3   594   1208
# 4   524   1055
# 5   595   1201
# 6   512   1041
# 7   492    996
# ...

# %%
#act_test first 10 rows
act_test.head(10)
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 0              National           60%     20.3  20.7     21.4     21.0
# 1               Alabama          100%     18.9  18.4     19.7     19.4
# 2                Alaska           65%     18.7  19.8     20.4     19.9
# 3               Arizona           62%     18.6  19.8     20.1     19.8
# 4              Arkansas          100%     18.9  19.0     19.7     19.5
# 5            California           31%     22.5  22.7     23.1     22.2
# 6              Colorado          100%     20.1  20.3     21.2     20.9
# 7           Connecticut           31%     25.5  24.6     25.6     24.6
# 8              Delaware           18%     24.1  23.4     24.8     23.6
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 0      21.0
# 1      19.2
# 2      19.8
# 3      19.7
# 4      19.4
# 5      22.8
# 6      20.8
# 7      25.2
# 8      24.1
# 9      24.2

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer:
#
# - The SAT, we have for each state, the 2017 participation rate, mean reading/writing score, mean math score, and mean total score. The mean scores have been provided rounded to the nearest whole number, therefore the average section scores will not necessarily sum exactly to produce the average total score for each state.
#
# - The ACT, we have for each state, the 2017 participation rate, scores for English, Math, Reading, Science, and then the Composite Score. The mean scores have been provided rounded to the nearest tenth of a decimal point.
#
# - We have to convert the participation percentages into numerical format.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# - The SAT participation rate appear to be a type object however, we should be converting it to a type float.
# - The ACT composite test contains an error entry in which 20.2x was entered instead of 20.2.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
#Minimum possible values for each test/subtest(SAT)

sat_test.describe().min()
# Out:
# Evidence-Based Reading and Writing    45.666901
# Math                                  51.000000
# Total                                 51.000000
# dtype: float64

# %%
#Maximum possible values for each test/subtest(SAT)

sat_test.describe().max()
# Out:
# Evidence-Based Reading and Writing     644.0
# Math                                   651.0
# Total                                 1295.0
# dtype: float64

# %%
#Minimum possible values for each test/subtest(ACT)
act_test.describe().min()
# Out:
# English    2.332132
# Math       1.963602
# Reading    2.048672
# Science    2.300000
# dtype: float64

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code

sat_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null object
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null object
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer: Both test Math are store in different types and Composite adn Participation are stored as a object.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
#Convert participation(sat) to float
def sat_to_float(percentage):
    return float(percentage.strip('%'))/100
    
sat_test['Participation']=sat_test['Participation'].apply(sat_to_float)

#Convert participation(act) to float
def act_to_float(percent):
    return float(percent.strip('%'))/100

act_test['Participation']=act_test['Participation'].apply(act_to_float)

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
#Convert composite to float and remove error value.
act_test['Composite'].replace('20.2x','20.2',inplace=True)

def composite_to_float(composite):
    return float(composite)
   

act_test['Composite'] = act_test['Composite'].apply(composite_to_float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code

act_test['Composite']
# Out:
# 0     21.0
# 1     19.2
# 2     19.8
# 3     19.7
# 4     19.4
# 5     22.8
# 6     20.8
# 7     25.2
# 8     24.1
# 9     24.2
# 10    19.8
# 11    21.4
# 12    19.0
# 13    22.3
# 14    21.4
# 15    22.6
# 16    21.9
# 17    21.7
# 18    20.0
# 19    19.5
# 20    24.3
# 21    23.6
# 22    25.4
# 23    24.1
# 24    21.5
# 25    18.6
# 26    20.4
# 27    20.3
# 28    21.4
# 29    17.8
# 30    25.5
# 31    23.9
# 32    19.7
# 33    24.2
# 34    19.1
# 35    20.3
# 36    22.0
# 37    19.4
# 38    21.8
# 39    23.7
# 40    24.0
# 41    18.7
# 42    21.8
# 43    19.8
# 44    20.7
# 45    20.3
# 46    23.6
# 47    23.8
# 48    21.9
# 49    20.4
# 50    20.5
# 51    20.2
# Name: Composite, dtype: float64

# %%
sat_test['Participation']
# Out:
# 0     0.05
# 1     0.38
# 2     0.30
# 3     0.03
# 4     0.53
# 5     0.11
# 6     1.00
# 7     1.00
# 8     1.00
# 9     0.83
# 10    0.61
# 11    0.55
# 12    0.93
# 13    0.09
# 14    0.63
# 15    0.02
# 16    0.04
# 17    0.04
# 18    0.04
# 19    0.95
# 20    0.69
# 21    0.76
# 22    1.00
# 23    0.03
# 24    0.02
# 25    0.03
# 26    0.10
# 27    0.03
# 28    0.26
# 29    0.96
# 30    0.70
# 31    0.11
# 32    0.67
# 33    0.49
# 34    0.02
# 35    0.12
# 36    0.07
# 37    0.43
# 38    0.65
# 39    0.71
# 40    0.50
# 41    0.03
# 42    0.05
# 43    0.62
# 44    0.03
# 45    0.60
# 46    0.65
# 47    0.64
# 48    0.14
# 49    0.03
# 50    0.03
# Name: Participation, dtype: float64

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
act_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
# State            52 non-null object
# Participation    52 non-null float64
# English          52 non-null float64
# Math             52 non-null float64
# Reading          52 non-null float64
# Science          52 non-null float64
# Composite        52 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
sat_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
# State                                 51 non-null object
# Participation                         51 non-null float64
# Evidence-Based Reading and Writing    51 non-null int64
# Math                                  51 non-null int64
# Total                                 51 non-null int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
sat_test.head(1)
# Out:
#      State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0  Alabama           0.05                                 593   572   1165

# %%
act_test.head(1)
# Out:
#       State  Participation  English  Math  Reading  Science  Composite
# 0  National            0.6     20.3  20.7     21.4     21.0       21.0

# %%
#code
#sat columns name changed
sat_test.columns = ['state',
                    'participation_sat',
                    'ebw',
                    'math_sat',
                    'total_sat']

sat_test
# Out:
#                    state  participation_sat  ebw  math_sat  total_sat
# 0                Alabama               0.05  593       572       1165
# 1                 Alaska               0.38  547       533       1080
# 2                Arizona               0.30  563       553       1116
# 3               Arkansas               0.03  614       594       1208
# 4             California               0.53  531       524       1055
# 5               Colorado               0.11  606       595       1201
# 6            Connecticut               1.00  530       512       1041
# 7               Delaware               1.00  503       492        996
# 8   District of Columbia               1.00  482       468        950
# 9                Florida               0.83  520       497       1017
# 10               Georgia               0.61  535       515       1050
# 11                Hawaii               0.55  544       541       1085
# ...

# %%
#act columns name changed
act_test.columns = ['state',
                    'participation_act',
                    'english_act',
                    'math_act',
                    'reading_act',
                    'science_act',
                    'composite_act']

act_test
# Out:
#                    state  participation_act  english_act  math_act  \
# 0               National               0.60         20.3      20.7
# 1                Alabama               1.00         18.9      18.4
# 2                 Alaska               0.65         18.7      19.8
# 3                Arizona               0.62         18.6      19.8
# 4               Arkansas               1.00         18.9      19.0
# 5             California               0.31         22.5      22.7
# 6               Colorado               1.00         20.1      20.3
# 7            Connecticut               0.31         25.5      24.6
# 8               Delaware               0.18         24.1      23.4
# 9   District of Columbia               0.32         24.4      23.5
# 10               Florida               0.73         19.0      19.4
# 11               Georgia               0.55         21.0      20.9
# 12                Hawaii               0.90         17.8      19.2
# ...

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# ## Data dictionary 2017/2018
#
# #### Data dictionary 2017
#
#
#
# |Feature      |Type      |Dataset  |Description|
# |---------    |------    |---------|-----------|
# |**state**        |object    |sat/act  |states|
# |**participation_sat**|float|sat|Statewide SAT Participation Rate, 2017|
# |**ebw**|integer|sat|State mean score, SAT Reading/Writing, 2017|
# |**math_sat**|integer|sat|State mean score, SAT Math, 2017|
# |**total_sat**|integer|sat|State mean total SAT score, 2017|
# |**participation_act**|float|act|Statewide ACT Participation Rate, 2017|
# |**english_act**|float|act|State mean score, ACT English, 2017|
# |**math_act**|float|act|State mean score, ACT English, 2017|
# |**reading_act**|float|act|State mean score, ACT Reading, 2017|
# |**science_act**|float|act|State mean score, ACT Science, 2017|
# |**composite_act**|float|act|State mean ACT Composite Score, 2017|
#
# #### Data dictionary 2018
#
# |Feature      |Type      |Dataset  |Description|
# |---------    |------    |---------|-----------|
# |**state**        |object    |sat/act  |states|
# |**participation_sat_2018**|float|sat|Statewide SAT Participation Rate, 2018|
# |**ebw_sat_2018**|integer|sat|State mean score, SAT Reading/Writing, 2018|
# |**math_sat_2018**|integer|sat|State mean score, SAT Math, 2018|
# |**total_sat_2018**|integer|sat|State mean total SAT score, 2018|
# |**participation_act_2018**|float|act|Statewide ACT Participation Rate, 2018|
# |**english_act_2018**|float|act|State mean score, ACT English, 2018|
# |**math_act_2018**|float|act|State mean score, ACT English, 2018|
# |**reading_act_2018**|float|act|State mean score, ACT Reading, 2018|
# |**science_act_2018**|float|act|State mean score, ACT Science, 2018|
# |**composite_act_2018**|float|act|State mean ACT Composite Score, 2018|

# %%
sat_test.columns = ['state',
                    'participation_sat',
                    'ebw',
                    'math_sat',
                    'total_sat']

act_test.columns = ['state',
                    'participation_act',
                    'english_act',
                    'math_act',
                    'reading_act',
                    'science_act',
                    'composite_act']

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
#Remove the extra state 'national'
act_test = act_test.drop(0)

# %%
act_test.reset_index()
# Out:
#     index                 state  participation_act  english_act  math_act  \
# 0       1               Alabama               1.00         18.9      18.4
# 1       2                Alaska               0.65         18.7      19.8
# 2       3               Arizona               0.62         18.6      19.8
# 3       4              Arkansas               1.00         18.9      19.0
# 4       5            California               0.31         22.5      22.7
# 5       6              Colorado               1.00         20.1      20.3
# 6       7           Connecticut               0.31         25.5      24.6
# 7       8              Delaware               0.18         24.1      23.4
# 8       9  District of Columbia               0.32         24.4      23.5
# 9      10               Florida               0.73         19.0      19.4
# 10     11               Georgia               0.55         21.0      20.9
# 11     12                Hawaii               0.90         17.8      19.2
# ...

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
#Code:

combined_2017=pd.merge(sat_test, act_test, on='state')

# %%
combined_2017
# Out:
#                    state  participation_sat  ebw  math_sat  total_sat  \
# 0                Alabama               0.05  593       572       1165
# 1                 Alaska               0.38  547       533       1080
# 2                Arizona               0.30  563       553       1116
# 3               Arkansas               0.03  614       594       1208
# 4             California               0.53  531       524       1055
# 5               Colorado               0.11  606       595       1201
# 6            Connecticut               1.00  530       512       1041
# 7               Delaware               1.00  503       492        996
# 8   District of Columbia               1.00  482       468        950
# 9                Florida               0.83  520       497       1017
# 10               Georgia               0.61  535       515       1050
# 11                Hawaii               0.55  544       541       1085
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code

combined_2017.to_csv('combined_2017.csv')

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat_2018 = pd.read_csv('/Users/Wilson/Documents/GitHub/classes_copy/project_1/data/sat_2018.csv')

act_2018 = pd.read_csv('/Users/Wilson/Documents/GitHub/classes_copy/project_1/data/act_2018_updated.csv')

# %%
#Clean data of sat_2018

#convert sat participation to float

def convert_float(percent_sat):
    return float(percent_sat.strip('%'))/100

sat_2018['Participation'] = sat_2018['Participation'].apply(convert_float)

# %%
#Change the column name of sat_2018

sat_2018.columns = ['state',
            'participation_sat_2018',
            'ebw_sat_2018',
            'math_sat_2018',
            'total_sat_2018']

# %%
#Convert atc_2018 int to float

def int_to_float(student_tested):
    return (float(student_tested))/100
act_2018['Percentage of Students Tested']=act_2018['Percentage of Students Tested'].apply(int_to_float)

# %%
#Change the atc_2018 'Composite' column to the back

act_2018 = act_2018[['State',
             'Percentage of Students Tested',
             'Average English Score',
             'Average Math Score',
             'Average Reading Score',
             'Average Science Score',
             'Average Composite Score']]

# %%
#Change the column name of act_2018

act_2018.columns = ['state',
                    'participation_act_2018',
                    'english_act_2018',
                    'math_act_2018',
                    'reading_act_2018',
                    'science_act_2018',
                    'composite_act_2018']

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#Merge sat_2018 and act_2018

combined_2018 = pd.merge(sat_2018,act_2018, on='state')

# %%
#Merge combined_2017 and combined_2018
final = pd.merge(combined_2017,combined_2018)

# %%
#Save file
final.to_csv('final.csv')

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:

final.describe()
# Out:
#        participation_sat         ebw    math_sat    total_sat  \
# count          51.000000   51.000000   51.000000    51.000000
# mean            0.398039  569.117647  547.627451  1126.098039
# std             0.352766   45.666901   84.909119    92.494812
# min             0.020000  482.000000   52.000000   950.000000
# 25%             0.040000  533.500000  522.000000  1055.500000
# 50%             0.380000  559.000000  548.000000  1107.000000
# 75%             0.660000  613.000000  599.000000  1212.000000
# max             1.000000  644.000000  651.000000  1295.000000
#
#        participation_act  english_act   math_act  reading_act  science_act  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean            0.652549    20.931373  21.182353    22.013725    21.041176
# std             0.321408     2.353677   1.981989     2.067271     3.182463
# min             0.080000    16.300000  18.000000    18.100000     2.300000
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Code:

def stan_dev(data):
    average = np.mean(data)
    empty = []
    for x in data:
        list_of_date = (x-average)**2
        empty.append(list_of_date)
    sqrt_errors = np.sqrt(sum(empty) / len(empty))
    return sqrt_errors

# %%
final_cal=final.iloc[:,1:]
final_cal.columns

sd = {final_cal.columns[i]:stan_dev(final_cal[x].values) for i, x in enumerate(final_cal.columns)}
sd
# Out:
# {'participation_sat': 0.3492907076664507,
#  'ebw': 45.21697020437866,
#  'math_sat': 84.07255521608297,
#  'total_sat': 91.58351056778743,
#  'participation_act': 0.3182417575123181,
#  'english_act': 2.3304876369363363,
#  'math_act': 1.9624620273436781,
#  'reading_act': 2.0469029314842646,
#  'science_act': 3.151107895464408,
#  'composite_act': 2.000786081581989,
#  'participation_sat_2018': 0.3694661922353941,
#  'ebw_sat_2018': 47.03460978357609,
#  'math_sat_2018': 47.30194550378352,
#  'total_sat_2018': 93.22742384464433,
#  'participation_act_2018': 0.33745194881997503,
#  'english_act_2018': 2.4222536143202795,
#  'math_act_2018': 2.0157072555557174,
#  'reading_act_2018': 2.145891884510421,
#  'science_act_2018': 1.851688548483354,
#  'composite_act_2018': 2.0855261815801147}

# %%
np.std(final)
# Out:
# participation_sat          0.349291
# ebw                       45.216970
# math_sat                  84.072555
# total_sat                 91.583511
# participation_act          0.318242
# english_act                2.330488
# math_act                   1.962462
# reading_act                2.046903
# science_act                3.151108
# composite_act              2.000786
# participation_sat_2018     0.369466
# ebw_sat_2018              47.034610
# math_sat_2018             47.301946
# total_sat_2018            93.227424
# participation_act_2018     0.337452
# english_act_2018           2.422254
# math_act_2018              2.015707
# reading_act_2018           2.145892
# science_act_2018           1.851689
# composite_act_2018         2.085526
# dtype: float64

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#code

#2017 SAT highest participation rates
sat_test[sat_test['participation_sat']==1.0].head()
# Out:
#                    state  participation_sat  ebw  math_sat  total_sat
# 6            Connecticut                1.0  530       512       1041
# 7               Delaware                1.0  503       492        996
# 8   District of Columbia                1.0  482       468        950
# 22              Michigan                1.0  509       495       1005

# %%
#2017 SAT lowest participation rates
sat_test[sat_test['participation_sat']==0.02].head()
# Out:
#            state  participation_sat  ebw  math_sat  total_sat
# 15          Iowa               0.02  641       635       1275
# 24   Mississippi               0.02  634       607       1242
# 34  North Dakota               0.02  635       621       1256

# %%
#2017 ACT highest participation rates
act_test[act_test['participation_act']==1.0].head()
# Out:
#         state  participation_act  english_act  math_act  reading_act  \
# 1     Alabama                1.0         18.9      18.4         19.7
# 4    Arkansas                1.0         18.9      19.0         19.7
# 6    Colorado                1.0         20.1      20.3         21.2
# 18   Kentucky                1.0         19.6      19.4         20.5
# 19  Louisiana                1.0         19.4      18.8         19.8
#
#     science_act  composite_act
# 1          19.4           19.2
# 4          19.5           19.4
# 6          20.9           20.8
# 18         20.1           20.0
# 19         19.6           19.5

# %%
#2017 ACT lowest participation rates
act_test[act_test['participation_act']==0.08].head()
# Out:
#     state  participation_act  english_act  math_act  reading_act  science_act  \
# 20  Maine               0.08         24.2      24.0         24.8         23.7
#
#     composite_act
# 20           24.3

# %%
#2018 SAT highest participation rates
sat_2018[sat_2018['participation_sat_2018']==1.0].head()
# Out:
#           state  participation_sat_2018  ebw_sat_2018  math_sat_2018  \
# 5      Colorado                     1.0           519            506
# 6   Connecticut                     1.0           535            519
# 7      Delaware                     1.0           505            492
# 12        Idaho                     1.0           508            493
# 22     Michigan                     1.0           511            499
#
#     total_sat_2018
# 5             1025
# 6             1053
# 7              998
# 12            1001
# 22            1011

# %%
#2018 SAT lowest participation rates
sat_2018[sat_2018['participation_sat_2018']==0.02].head()
# Out:
#            state  participation_sat_2018  ebw_sat_2018  math_sat_2018  \
# 34  North Dakota                    0.02           640            643
#
#     total_sat_2018
# 34            1283

# %%
#2018 ACT highest participation rates
act_2018[act_2018['participation_act_2018']==1.0].head()
# Out:
#           state  participation_act_2018  english_act_2018  math_act_2018  \
# 0       Alabama                     1.0              18.9           18.3
# 3      Arkansas                     1.0              19.1           18.9
# 17     Kentucky                     1.0              19.9           19.7
# 18    Louisiana                     1.0              19.0           18.5
# 24  Mississippi                     1.0              18.2           18.1
#
#     reading_act_2018  science_act_2018  composite_act_2018
# 0               19.6              19.0                19.1
# 3               19.7              19.4                19.4
# 17              20.8              20.1                20.2
# 18              19.6              19.1                19.2
# 24              18.9              18.6                18.6

# %%
#2018 ACT lowest participation rates
act_2018[act_2018['participation_act_2018']==0.07].head()
# Out:
#     state  participation_act_2018  english_act_2018  math_act_2018  \
# 19  Maine                    0.07              23.8           23.6
#
#     reading_act_2018  science_act_2018  composite_act_2018
# 19              24.7              23.4                24.0

# %%
final.describe()
# Out:
#        participation_sat         ebw    math_sat    total_sat  \
# count          51.000000   51.000000   51.000000    51.000000
# mean            0.398039  569.117647  547.627451  1126.098039
# std             0.352766   45.666901   84.909119    92.494812
# min             0.020000  482.000000   52.000000   950.000000
# 25%             0.040000  533.500000  522.000000  1055.500000
# 50%             0.380000  559.000000  548.000000  1107.000000
# 75%             0.660000  613.000000  599.000000  1212.000000
# max             1.000000  644.000000  651.000000  1295.000000
#
#        participation_act  english_act   math_act  reading_act  science_act  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean            0.652549    20.931373  21.182353    22.013725    21.041176
# std             0.321408     2.353677   1.981989     2.067271     3.182463
# min             0.080000    16.300000  18.000000    18.100000     2.300000
# ...

# %%
#Which states have the highest and lowest mean total/composite scores for the:

#2017 SAT highest mean total scores
sat_test[sat_test['total_sat']==1295.].head()
# Out:
#         state  participation_sat  ebw  math_sat  total_sat
# 23  Minnesota               0.03  644       651       1295

# %%
#2017 SAT lowest mean total scores
sat_test[sat_test['total_sat']==950.].head()
# Out:
#                   state  participation_sat  ebw  math_sat  total_sat
# 8  District of Columbia                1.0  482       468        950

# %%
#2017 ACT highest mean composite scores
act_test[act_test['composite_act']==25.5].head()
# Out:
#             state  participation_act  english_act  math_act  reading_act  \
# 30  New Hampshire               0.18         25.4      25.1         26.0
#
#     science_act  composite_act
# 30         24.9           25.5

# %%
#2017 ACT lowest mean composite scores
act_test[act_test['composite_act']==17.8].head()
# Out:
#      state  participation_act  english_act  math_act  reading_act  \
# 29  Nevada                1.0         16.3      18.0         18.1
#
#     science_act  composite_act
# 29         18.2           17.8

# %%
#2018 SAT highest mean total scores
sat_2018[sat_2018['total_sat_2018']==1298.].head()
# Out:
#         state  participation_sat_2018  ebw_sat_2018  math_sat_2018  \
# 23  Minnesota                    0.04           643            655
#
#     total_sat_2018
# 23            1298

# %%
#2018 SAT lowest mean total scores
sat_2018[sat_2018['total_sat_2018']==977.].head()
# Out:
#                   state  participation_sat_2018  ebw_sat_2018  math_sat_2018  \
# 8  District of Columbia                    0.92           497            480
#
#    total_sat_2018
# 8             977

# %%
#2018 ACT highest mean composite scores
act_2018[act_2018['composite_act_2018']==25.6].head()
# Out:
#          state  participation_act_2018  english_act_2018  math_act_2018  \
# 6  Connecticut                    0.26              26.0           24.8
#
#    reading_act_2018  science_act_2018  composite_act_2018
# 6              26.1              24.9                25.6

# %%
#2018 ACT lowest mean composite scores
act_2018[act_2018['composite_act_2018']==17.7].head()
# Out:
#      state  participation_act_2018  english_act_2018  math_act_2018  \
# 28  Nevada                     1.0              16.6           17.8
#
#     reading_act_2018  science_act_2018  composite_act_2018
# 28              18.0              17.9                17.7

# %%
#Do any states with 100% participation on a given test have a rate change year-to-year?

#District of Columbia and Idaho

# %%
#Do any states show have >50% participation on both tests either year?
#2017 SAT participation
sat_test[sat_test['participation_sat']>0.5].head()
# Out:
#                   state  participation_sat  ebw  math_sat  total_sat
# 4            California               0.53  531       524       1055
# 6           Connecticut               1.00  530       512       1041
# 7              Delaware               1.00  503       492        996
# 8  District of Columbia               1.00  482       468        950
# 9               Florida               0.83  520       497       1017

# %%
#2017 ACT participation
act_test[act_test['participation_act']>0.5].head()
# Out:
#       state  participation_act  english_act  math_act  reading_act  \
# 1   Alabama               1.00         18.9      18.4         19.7
# 2    Alaska               0.65         18.7      19.8         20.4
# 3   Arizona               0.62         18.6      19.8         20.1
# 4  Arkansas               1.00         18.9      19.0         19.7
# 6  Colorado               1.00         20.1      20.3         21.2
#
#    science_act  composite_act
# 1         19.4           19.2
# 2         19.9           19.8
# 3         19.8           19.7
# 4         19.5           19.4
# 6         20.9           20.8

# %%
#2018 SAT participation
sat_2018[sat_2018['participation_sat_2018']>0.5].head()
# Out:
#                   state  participation_sat_2018  ebw_sat_2018  math_sat_2018  \
# 4            California                    0.60           540            536
# 5              Colorado                    1.00           519            506
# 6           Connecticut                    1.00           535            519
# 7              Delaware                    1.00           505            492
# 8  District of Columbia                    0.92           497            480
#
#    total_sat_2018
# 4            1076
# 5            1025
# 6            1053
# 7             998
# 8             977

# %%
#2018 ACT participation
act_2018[act_2018['participation_act_2018']>0.5].head()
# Out:
#        state  participation_act_2018  english_act_2018  math_act_2018  \
# 0    Alabama                    1.00              18.9           18.3
# 2    Arizona                    0.66              18.2           19.4
# 3   Arkansas                    1.00              19.1           18.9
# 9    Florida                    0.66              19.2           19.3
# 10   Georgia                    0.53              20.9           20.7
#
#     reading_act_2018  science_act_2018  composite_act_2018
# 0               19.6              19.0                19.1
# 2               19.5              19.2                19.2
# 3               19.7              19.4                19.4
# 9               21.1              19.5                19.9
# 10              21.2              21.4                21.4

# %%
#For SAT California, Connecticut, Delaware they consistently maintained more than 50% participation on both years.

#For ACT Alabama, Arizona and Arkansas they consistently maintained more than 50% participation on both years.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import seaborn as sns

final_participation = final.corr()

plt.figure(figsize=(22,12))
plt.title("Overall correlation between SAT & ACT 2017 & 2018", fontsize = 15);

sns.heatmap(final_participation,annot=True, square=True,linewidth=1,linecolor='black',cmap='coolwarm');

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        # Set titles, labels, etc here for each subplot

# %%
final.head(2)
# Out:
#      state  participation_sat  ebw  math_sat  total_sat  participation_act  \
# 0  Alabama               0.05  593       572       1165               1.00
# 1   Alaska               0.38  547       533       1080               0.65
#
#    english_act  math_act  reading_act  science_act  ...  \
# 0         18.9      18.4         19.7         19.4  ...
# 1         18.7      19.8         20.4         19.9  ...
#
#    participation_sat_2018  ebw_sat_2018  math_sat_2018  total_sat_2018  \
# 0                    0.06           595            571            1166
# 1                    0.43           562            544            1106
#
#    participation_act_2018  english_act_2018  math_act_2018  reading_act_2018  \
# 0                    1.00              18.9           18.3              19.6
# 1                    0.33              19.8           20.6              21.6
#
#    science_act_2018  composite_act_2018
# 0              19.0                19.1
# ...

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
final.head(2)
# Out:
#      state  participation_sat  ebw  math_sat  total_sat  participation_act  \
# 0  Alabama               0.05  593       572       1165               1.00
# 1   Alaska               0.38  547       533       1080               0.65
#
#    english_act  math_act  reading_act  science_act  ...  \
# 0         18.9      18.4         19.7         19.4  ...
# 1         18.7      19.8         20.4         19.9  ...
#
#    participation_sat_2018  ebw_sat_2018  math_sat_2018  total_sat_2018  \
# 0                    0.06           595            571            1166
# 1                    0.43           562            544            1106
#
#    participation_act_2018  english_act_2018  math_act_2018  reading_act_2018  \
# 0                    1.00              18.9           18.3              19.6
# 1                    0.33              19.8           20.6              21.6
#
#    science_act_2018  composite_act_2018
# 0              19.0                19.1
# ...

# %%
# Code

def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2,figsize=(12,10)) # You'll want to specify your figsize
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column]) # feel free to add more settings
        ax[i].set_xlabel(list_of_xlabels[i])
        ax[i].set_ylabel(list_of_ylabels[i])
        ax[i].set_title(list_of_titles[i]) # Set titles, labels, etc here for each subplot

# %%
#Participation rates for SAT & ACT 2017
subplot_histograms(final, ['participation_sat', 'participation_act'], ['SAT 2017 Participation', 'ACT 2017 Participation'],
                   ['SAT Participation', 'ACT Participation'], ['Frequency', 'Frequency'])

# %%
#Participation rates for SAT & ACT 2018
subplot_histograms(final, ['participation_sat_2018', 'participation_act_2018'], ['SAT 2018 Participation', 'ACT 2018 Participation'],
                   ['SAT Participation', 'ACT Participation'], ['Frequency', 'Frequency'])

# %%
#Math scores for SAT & ACT 2017

subplot_histograms(final, ['math_sat', 'math_act'], ['SAT Math 2017 Scores', 'ACT Math 2017 Scores'],
                   ['SAT Math Score', 'ACT Math Score'], ['Frequency', 'Frequency'])

# %%
#Math scores for SAT & ACT 2018

subplot_histograms(final, ['math_sat_2018', 'math_act_2018'], ['SAT Math 2018 Scores', 'ACT Math 2018 Scores'],
                   ['SAT Math Score', 'ACT Math Score'], ['Frequency', 'Frequency'])

# %%
#Reading/verbal scores for SAT & ACT 2017

subplot_histograms(final, ['ebw', 'reading_act'], ['SAT Reading/verbal 2017 Scores', 'ACT Reading/verbal 2017 Scores'],
                   ['SAT Reading/verbal Score', 'ACT Reading/verbal Score'], ['Frequency', 'Frequency'])

# %%
#Reading/verbal scores for SAT & ACT 2018

subplot_histograms(final, ['ebw_sat_2018', 'reading_act_2018'], ['SAT Reading/verbal 2018 Scores', 'ACT Reading/verbal 2018 Scores'],
                   ['SAT Reading/verbal Score', 'ACT Reading/verbal Score'], ['Frequency', 'Frequency'])

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Code

final.head(3)
# Out:
#      state  participation_sat  ebw  math_sat  total_sat  participation_act  \
# 0  Alabama               0.05  593       572       1165               1.00
# 1   Alaska               0.38  547       533       1080               0.65
# 2  Arizona               0.30  563       553       1116               0.62
#
#    english_act  math_act  reading_act  science_act  ...  \
# 0         18.9      18.4         19.7         19.4  ...
# 1         18.7      19.8         20.4         19.9  ...
# 2         18.6      19.8         20.1         19.8  ...
#
#    participation_sat_2018  ebw_sat_2018  math_sat_2018  total_sat_2018  \
# 0                    0.06           595            571            1166
# 1                    0.43           562            544            1106
# 2                    0.29           577            572            1149
#
#    participation_act_2018  english_act_2018  math_act_2018  reading_act_2018  \
# ...

# %%
fig, ax = plt.subplots(ncols=2, nrows=2, figsize=(12, 12))
sns.scatterplot(final.loc[:,'math_sat'], final.loc[:,'math_act'],ax=ax[0,0])
sns.scatterplot(final.loc[:,'ebw'], final.loc[:,'reading_act'],ax=ax[0,1])
sns.scatterplot(final.loc[:,'total_sat'], final.loc[:,'composite_act'],ax=ax[1,0])
sns.scatterplot(final.loc[:,'total_sat'], final.loc[:,'total_sat_2018'],ax=ax[1,1])

ax[0,0].set_title('SAT vs. ACT math scores for 2017', fontsize=12)
ax[0,1].set_title('SAT vs. ACT verbal/reading scores for 2017', fontsize=12)
ax[1,0].set_title('SAT vs. ACT total/composite scores for 2017', fontsize=12)
ax[1,1].set_title('Total scores for SAT 2017 vs. 2018', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Total scores for SAT 2017 vs. 2018')

# %%
fig, ax = plt.subplots(figsize=(6, 6))
sns.scatterplot(final.loc[:,'composite_act'], final.loc[:,'composite_act_2018'])
ax.set_title('Composite scores for ACT 2017 vs. 2018', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Composite scores for ACT 2017 vs. 2018')

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# Code

final.head(3)
# Out:
#      state  participation_sat  ebw  math_sat  total_sat  participation_act  \
# 0  Alabama               0.05  593       572       1165               1.00
# 1   Alaska               0.38  547       533       1080               0.65
# 2  Arizona               0.30  563       553       1116               0.62
#
#    english_act  math_act  reading_act  science_act  ...  \
# 0         18.9      18.4         19.7         19.4  ...
# 1         18.7      19.8         20.4         19.9  ...
# 2         18.6      19.8         20.1         19.8  ...
#
#    participation_sat_2018  ebw_sat_2018  math_sat_2018  total_sat_2018  \
# 0                    0.06           595            571            1166
# 1                    0.43           562            544            1106
# 2                    0.29           577            572            1149
#
#    participation_act_2018  english_act_2018  math_act_2018  reading_act_2018  \
# ...

# %%
sns.boxplot(data=final.loc[:,['participation_sat', 'participation_act']])
plt.ylabel('frequency')
plt.title('Participation rate between SAT and ACT 2017');

# %%
sns.boxplot(data=final.loc[:,['participation_sat_2018', 'participation_act_2018']])
plt.ylabel('frequency')
plt.title('Participation rate between SAT and ACT 2018');

# %%
sns.boxplot(data=final.loc[:,['participation_sat', 'participation_sat_2018']])
plt.ylabel('frequency')
plt.title('Participation rate between SAT 2017 & 2018');

# %%
sns.boxplot(data=final.loc[:,['participation_act', 'participation_act_2018']])
plt.ylabel('frequency')
plt.title('Participation rate between ACT 2017 & 2018');

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
final.describe()
# Out:
#        participation_sat         ebw    math_sat    total_sat  \
# count          51.000000   51.000000   51.000000    51.000000
# mean            0.398039  569.117647  547.627451  1126.098039
# std             0.352766   45.666901   84.909119    92.494812
# min             0.020000  482.000000   52.000000   950.000000
# 25%             0.040000  533.500000  522.000000  1055.500000
# 50%             0.380000  559.000000  548.000000  1107.000000
# 75%             0.660000  613.000000  599.000000  1212.000000
# max             1.000000  644.000000  651.000000  1295.000000
#
#        participation_act  english_act   math_act  reading_act  science_act  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean            0.652549    20.931373  21.182353    22.013725    21.041176
# std             0.321408     2.353677   1.981989     2.067271     3.182463
# min             0.080000    16.300000  18.000000    18.100000     2.300000
# ...

# %% [markdown]
# # Summarize the underlying distributions (in words & statistics)
#
# **participation_sat** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 0.98.
#
# **ebw** - Shape: This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data range is 162.
#
# **math_sat** - This distribution is negatively skewed and its median is skewed mostly to the left as most of the scores are concentrated within 500-600. The data range is 599.
#
# **total_sat** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data range is 345.
#
# **participation_act** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered negatively skewed and the data range is 0.92.
#
# **english_act** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 9.2.
#
# **math_act** - It is considered positively skewed and the data spread is 7.3.
#
# **reading_act** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 7.9.
#
# **science_act** - This distribution is negatively skewed and its median is skewed mostly to the left as most of the scores are concentrated within the 20 region. The data range is 22.6.
#
# **composite_act** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 7.7.
#
# **participation_sat_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 0.98.
#
# **ebw_sat_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 163.
#
# **math_sat_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 175.
#
# **total_sat_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 321.
#
# **participation_act_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. The mean and median is relatively similar with 2 distinct mode. And the data spread is 0.93.
#
# **english_act_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 9.4.
#
# **math_act_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 7.4.
#
# **reading_act_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 8.1.
#
# **science_act_2018** - This distribution is relatively normal, however, it still slightly shows two frequent mode within the distribution. The data spread is 7.
#
# **composite_act_2018** - This distribution is bimodal distribution with two peaks in the distribution. The two peaks are most likely caused by two frequent scores recurring within the data. It is considered positively skewed and the data spread is 7.9.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: We generally do not observe a normal distribution trend as most of the distribution exist extreme values which skewed the result drastically or there were two peaks within the distribution due to biasness towards two regions data.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
fig, ax = plt.subplots(ncols=2, nrows=4, figsize=(10, 15))
sns.distplot(final['math_sat'], bins=15, kde=True, ax=ax[0,0])
sns.distplot(final['math_sat_2018'], bins=15, kde=True, ax=ax[0,1])
sns.distplot(final['math_act'], bins=15, kde=True, ax=ax[1,0])
sns.distplot(final['math_act_2018'], bins=15, kde=True, ax=ax[1,1])
sns.distplot(final['reading_act'], bins=15, kde=True, ax=ax[2,0])
sns.distplot(final['reading_act_2018'], bins=15, kde=True, ax=ax[2,1])
sns.distplot(final['participation_act']*100, bins=15, kde=True, ax=ax[3,0])
sns.distplot(final['participation_sat'], bins=15, kde=True, ax=ax[3,1])

# %% [markdown]
# Answer: As we see from the above histograms, Math ACT and reading ACT scores are relatively close to normal distributed. However, rates and math SAT 2017 they are NOT normally distributed but are negatively and positively skewed due to the mean being higher or lower than the median in both. This is due to the presence of region specific outliers that pull the mean to be significantly higher than the median
# This will affect our answers in that estimates made from this data will be negatively or positively biased.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer:

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer: It is not appropriate to compare SAT and ACT math scores as they are based on a different scoring system. Thus, it will not give an accurate conclusion when compared.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# Evidence of Selection Bias Effect in Colorado and Illinois
#
# Colorado and Illinois, which have both seen dramatic increases in SAT participation in the previous year. Both states implemented mandatory SAT testing. In doing so, as mentioned above, they both saw significant decreases in SAT scores(1201 in 2017 to 1025 in 2018). The most distinct changed is Colorado. This is likely attributable in part to a large increase in SAT participation (11% in 2017 to 100% in 2018), which might dilute the quality of the average score.

# %%
#Total SAT Score for 2017 & 2018
final.loc[final['state']=='Colorado',['total_sat','total_sat_2018']]
# Out:
#    total_sat  total_sat_2018
# 5       1201            1025

# %%
#Participation rate for SAT 2017 & 2018(Colorado)
final.loc[final['state']=='Colorado',['participation_sat','participation_sat_2018']]
# Out:
#    participation_sat  participation_sat_2018
# 5               0.11                     1.0

# %%
#Participation rate for SAT 2017 & 2018(Illinois)
final.loc[final['state']=='Illinois',['participation_sat','participation_sat_2018']]
# Out:
#     participation_sat  participation_sat_2018
# 13               0.09                    0.99

# %%
sns.scatterplot(final.loc[:,'total_sat'], final.loc[:,'total_sat_2018']);

# %% [markdown]
# Again, we observe a high correlation between ACT Composite scores in 2017 and 2018 across the states. There are two outliers, these states have huge gains in ACT scores in the past year. Therefore, we can assume these states to be Illinois and Colorado again. With the increases in SAT participation, there is a sizeable decreases in ACT participation, which indirectly led to a higher mean score.

# %%
#Participation rate for ACT 2017 & 2018 (Colorado)
final.loc[final['state']=='Colorado',['participation_act','participation_act_2018']]
# Out:
#    participation_act  participation_act_2018
# 5                1.0                     0.3

# %%
#Participation rate for ACT 2017 & 2018 (Illinois)
final.loc[final['state']=='Illinois',['participation_act','participation_act_2018']]
# Out:
#     participation_act  participation_act_2018
# 13               0.93                    0.43

# %%
#Total ACT Score for 2017 & 2018 (Colorado)
final.loc[final['state']=='Colorado',['composite_act','composite_act_2018']]
# Out:
#    composite_act  composite_act_2018
# 5           20.8                23.9

# %%
#Total ACT Score for 2017 & 2018 (Illinois)
final.loc[final['state']=='Illinois',['composite_act','composite_act_2018']]
# Out:
#     composite_act  composite_act_2018
# 13           21.4                23.9

# %%
sns.scatterplot(final.loc[:,'composite_act'], final.loc[:,'composite_act_2018']);

# %% [markdown]
# West Virginia also contain an interesting trend, in 2018 it saw one of the largest increase in SAT participation not involving a mandatory requirement. It was a 100% increase in participation from 0.14 to 0.28. This participation increase was the result of the ACT statewide contract ended without renewal in 2018, and West Virginia subsequently agreed to cover SAT test costs for all public school students.

# %%
final.loc[final['state']=='West Virginia',['participation_sat','participation_sat_2018']]
# Out:
#     participation_sat  participation_sat_2018
# 48               0.14                    0.28

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# The ACT and SAT participation distributions mirror each other, with states tending to prefer one test or the other. ACT shows a large group of highly committed states while SAT shows a larger group of states with 50-80% particpation, as well as a smaller set of highly committed states.
#
# ACT and SAT scores are inversely correlated with their respective participation rates. This is likely due to selection bias, as low participation means those who are participating tend to be higher achieving, and high participation means diluted quality of performance.
#
# There are strong regional (and possibly political) affiliations associated with ACT versus SAT preference. Coastal progressive states tend to favor the SAT, while Midwestern and Mountain conservative states tend to favor the ACT.
#
# The SAT made clear gains in 2018 relative to the ACT. The states making these gains tended to be states in the 10-15% participation range. Targeting states in similar positions in the 2018 distribution should be promising for the College Board moving forward.
